# %%
import pandas as pd
import numpy as np
#df = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding='iso-8859-1')
df = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding="ISO-8859-1")
df.head()
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
df.columns = df.columns.str.replace('_£', '')
df.head()
# Out:
#               pmid/pmcid publisher           journal_title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        article_title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   cost_charged_to_wellcome_inc_vat_when_charged
# 0                                         £0.00
# 1                                      £2381.04
# 2                                       £642.56
# 3                                       £669.64
# ...

# %%
#df.Cost.replace('£', '')
#df['Cost'] = df['Cost'].str.replace('£','')
#df.cost.str.replace('£', '')
#df[['Cost']] = df[['Cost']].apply(pd.to_numeric)
cost = df.cost_charged_to_wellcome_inc_vat_when_charged.str.split('£', expand=True)[1].astype(np.float)
print('Mean: ' + str(round(cost.mean(), 2))), 
print('Median: ' + str(round(cost.median(), 2)))
print('Standard Deviation: ' + str(round(cost.std(), 2)))
#def Stats(df):
#    print("Mean: ",np.mean(df))
#    print("Median: ",np.median(df))
#    print("Standard Deviation:",np.std(df))

#Stats(df)
# Out:
# Mean: 24206.44
# Median: 1889.95
# Standard Deviation: 147300.99

# %%
# five most common journals 
#df = df.groupby('journal_title').count()
#grouped = df.groupby('journal_title').reset_index()
grouped = df.groupby('journal_title').count()
#grouped.sort_values('journal_title', ascending=False)
#.reset_index().sort_values("article_title", ascending=False)
grouped.head(10)
# Out:
#                            pmid/pmcid  publisher  article_title  \
# journal_title
# ACS Chemical Biology                4          5              5
# ACS Chemical Neuroscience           1          1              1
# ACS NANO                            1          1              1
# ACS Nano                            1          1              1
# ACTA F                              1          1              1
# AGE                                 1          1              1
# AIDS                                3          3              3
# AIDS Behav                          1          1              1
# AIDS Care                           2          2              2
# AIDS Journal                        1          1              1
#
#                            cost_charged_to_wellcome_inc_vat_when_charged
# journal_title
# ACS Chemical Biology                                                   5
# ACS Chemical Neuroscience                                              1
# ...
